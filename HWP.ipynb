# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import font_manager, rc
font_name = font_manager.FontProperties(fname="c:/Windows/Fonts/malgun.ttf").get_name()
rc('font', family=font_name)

# %%
wind=pd.read_csv('HW/wind.csv', encoding='cp949')
air=pd.read_csv('HW/air.csv', encoding='cp949')

# %%
wind.T
# Out:
#                           0           1           2           3           4    \
# 지점                        108         108         108         108         108
# 지점명                        서울          서울          서울          서울          서울
# 일시                 2020-01-01  2020-01-02  2020-01-03  2020-01-04  2020-01-05
# 최대 순간 풍속(m/s)             4.8         6.7         5.8         8.5         4.4
# 최대 순간 풍속 풍향(16방위)          50         250         270         340         180
# 최대 순간풍속 시각(hhmi)          906        1437        1122        1206        1312
# 최대 풍속(m/s)                2.6           4         3.5         4.5         2.9
# 최대 풍속 풍향(16방위)             50         290         270         320          70
# 최대 풍속 시각(hhmi)            904        1525        1422        1228        2335
# 평균 풍속(m/s)                0.6         1.2         1.7         1.9         1.1
# 풍정합(100m)                 509         996        1508        1623         985
# ...

# %%
air.T
# Out:
#                        0           1           2           3           4    \
# 지점                     108         108         108         108         108
# 지점명                     서울          서울          서울          서울          서울
# 일시              2020-01-01  2020-01-02  2020-01-03  2020-01-04  2020-01-05
# 일 미세먼지 농도(㎍/㎥)          39          69          78          63          62
#
#                        5           6           7           8           9    \
# 지점                     108         108         108         108         108
# 지점명                     서울          서울          서울          서울          서울
# 일시              2020-01-06  2020-01-07  2020-01-08  2020-01-09  2020-01-10
# 일 미세먼지 농도(㎍/㎥)          46          10          32          54          73
#
#                    ...             289         290         291         292  \
# 지점                 ...             108         108         108         108
# ...

# %%
newdata=pd.merge(air,wind,on=['지점','일시','지점명'])
newdata.T
# Out:
#                           0           1           2           3           4    \
# 지점                        108         108         108         108         108
# 지점명                        서울          서울          서울          서울          서울
# 일시                 2020-01-01  2020-01-02  2020-01-03  2020-01-04  2020-01-05
# 일 미세먼지 농도(㎍/㎥)             39          69          78          63          62
# 최대 순간 풍속(m/s)             4.8         6.7         5.8         8.5         4.4
# 최대 순간 풍속 풍향(16방위)          50         250         270         340         180
# 최대 순간풍속 시각(hhmi)          906        1437        1122        1206        1312
# 최대 풍속(m/s)                2.6           4         3.5         4.5         2.9
# 최대 풍속 풍향(16방위)             50         290         270         320          70
# 최대 풍속 시각(hhmi)            904        1525        1422        1228        2335
# 평균 풍속(m/s)                0.6         1.2         1.7         1.9         1.1
# ...

# %%
del newdata['지점명']
del newdata['지점']

# %%
newdata.T
# Out:
#                           0           1           2           3           4    \
# 일시                 2020-01-01  2020-01-02  2020-01-03  2020-01-04  2020-01-05
# 일 미세먼지 농도(㎍/㎥)             39          69          78          63          62
# 최대 순간 풍속(m/s)             4.8         6.7         5.8         8.5         4.4
# 최대 순간 풍속 풍향(16방위)          50         250         270         340         180
# 최대 순간풍속 시각(hhmi)          906        1437        1122        1206        1312
# 최대 풍속(m/s)                2.6           4         3.5         4.5         2.9
# 최대 풍속 풍향(16방위)             50         290         270         320          70
# 최대 풍속 시각(hhmi)            904        1525        1422        1228        2335
# 평균 풍속(m/s)                0.6         1.2         1.7         1.9         1.1
# 풍정합(100m)                 509         996        1508        1623         985
# 최다풍향(16방위)                 50          50         290          50          50
#
# ...

# %%
nc_air=newdata.sort_values('일 미세먼지 농도(㎍/㎥)',ascending=True).head(75)
bad_air=newdata.sort_values('일 미세먼지 농도(㎍/㎥)',ascending=False).head(75)
hi_wind=newdata.sort_values('평균 풍속(m/s)',ascending=False).head(75)
nc_air=nc_air.sort_values('일시',ascending=True)
bad_air=bad_air.sort_values('일시',ascending=True)

#일일 미세먼지가 높은날과 낮은날을 알기 위한 데이터 추출

# %%
del nc_air['최대 순간 풍속(m/s)']
del nc_air['최대 순간 풍속 풍향(16방위)']
del nc_air['최대 순간풍속 시각(hhmi)']
del nc_air['최대 풍속(m/s)']
del nc_air['최대 풍속 풍향(16방위)']
del nc_air['최대 풍속 시각(hhmi)']
del nc_air['풍정합(100m)']
nc_air.T
# Out:
#                        6           12          25          26          27   \
# 일시              2020-01-07  2020-01-13  2020-01-26  2020-01-27  2020-01-28
# 일 미세먼지 농도(㎍/㎥)          10          28          28          10          11
# 평균 풍속(m/s)               4         2.3         2.7         4.6         2.6
# 최다풍향(16방위)              70         290          70          70          50
#
#                        28          29          33          35          47   \
# 일시              2020-01-29  2020-01-30  2020-02-03  2020-02-05  2020-02-18
# 일 미세먼지 농도(㎍/㎥)          15          17          29          28          29
# 평균 풍속(m/s)             2.1         1.8         3.1         3.3         2.3
# 최다풍향(16방위)              70          70         270         320         290
#
#                    ...             210         211         219         220  \
# 일시                 ...      2020-09-26  2020-09-27  2020-10-08  2020-10-09
# ...

# %%
del bad_air['최대 순간 풍속(m/s)']
del bad_air['최대 순간 풍속 풍향(16방위)']
del bad_air['최대 순간풍속 시각(hhmi)']
del bad_air['최대 풍속(m/s)']
del bad_air['최대 풍속 풍향(16방위)']
del bad_air['최대 풍속 시각(hhmi)']
del bad_air['풍정합(100m)']
bad_air.T
# Out:
#                        1           2           3           4           9    \
# 일시              2020-01-02  2020-01-03  2020-01-04  2020-01-05  2020-01-10
# 일 미세먼지 농도(㎍/㎥)          69          78          63          62          73
# 평균 풍속(m/s)             1.2         1.7         1.9         1.1         1.5
# 최다풍향(16방위)              50         290          50          50         290
#
#                        10          16          17          18          22   \
# 일시              2020-01-11  2020-01-17  2020-01-18  2020-01-19  2020-01-23
# 일 미세먼지 농도(㎍/㎥)          60          64          68          72          71
# 평균 풍속(m/s)             1.9         1.5         1.8         2.2           2
# 최다풍향(16방위)             290         290         270         270         290
#
#                    ...             278         279         288         289  \
# 일시                 ...      2020-12-10  2020-12-12  2020-12-21  2020-12-22
# ...

# %%
del hi_wind['최대 순간 풍속(m/s)']
del hi_wind['최대 순간 풍속 풍향(16방위)']
del hi_wind['최대 순간풍속 시각(hhmi)']
del hi_wind['최대 풍속(m/s)']
del hi_wind['최대 풍속 풍향(16방위)']
del hi_wind['최대 풍속 시각(hhmi)']
del hi_wind['풍정합(100m)']
hi_wind.T
# Out:
#                        77          26          110         54          196  \
# 일시              2020-03-19  2020-01-27  2020-04-21  2020-02-25  2020-09-08
# 일 미세먼지 농도(㎍/㎥)          57          10          33          28          27
# 평균 풍속(m/s)             4.8         4.6         4.4         4.2         4.2
# 최다풍향(16방위)             270          70         290          70         230
#
#                        297         111         51          6           46   \
# 일시              2020-12-30  2020-04-22  2020-02-22  2020-01-07  2020-02-16
# 일 미세먼지 농도(㎍/㎥)          47          64          75          10          58
# 평균 풍속(m/s)             4.1           4           4           4           4
# 최다풍향(16방위)             270         290         270          70         270
#
#                    ...             160         231         266         215  \
# 일시                 ...      2020-06-15  2020-10-22  2020-11-28  2020-10-04
# ...

# %%
newdata['최다풍향(16방위)'].value_counts()
#바람 방향의 범위를 지정하기위하여 컬럼 조회
# Out:
# 290    71
# 270    68
# 50     53
# 70     22
# 250    20
# 320    19
# 20     14
# 90     10
# 230     7
# 200     5
# 180     5
# 110     2
# 360     1
# 160     1
# 140     1
# Name: 최다풍향(16방위), dtype: int64

# %%
n_wind0=(newdata['최다풍향(16방위)']>=315)
n_wind1=(newdata['최다풍향(16방위)']<=45)
n_wind=newdata[n_wind0 | n_wind1]

# %%
e_wind0=(newdata['최다풍향(16방위)']>=45)
e_wind1=(newdata['최다풍향(16방위)']<=135)
e_wind=newdata[e_wind0 & e_wind1]
#e_wind.T
#동풍

# %%
s_wind0=(newdata['최다풍향(16방위)']>=135)
s_wind1=(newdata['최다풍향(16방위)']<=225)
s_wind=newdata[s_wind0 & s_wind1]
#s_wind.T
#남풍

# %%
w_wind0=(newdata['최다풍향(16방위)']>=225)
w_wind1=(newdata['최다풍향(16방위)']<=315)
w_wind=newdata[w_wind0 & w_wind1]
#w_wind.T
#서풍

# %%
#newdata['방향(4방위)']= 0

# %%
newdata.T
# Out:
#                           0           1           2           3           4    \
# 일시                 2020-01-01  2020-01-02  2020-01-03  2020-01-04  2020-01-05
# 일 미세먼지 농도(㎍/㎥)             39          69          78          63          62
# 최대 순간 풍속(m/s)             4.8         6.7         5.8         8.5         4.4
# 최대 순간 풍속 풍향(16방위)          50         250         270         340         180
# 최대 순간풍속 시각(hhmi)          906        1437        1122        1206        1312
# 최대 풍속(m/s)                2.6           4         3.5         4.5         2.9
# 최대 풍속 풍향(16방위)             50         290         270         320          70
# 최대 풍속 시각(hhmi)            904        1525        1422        1228        2335
# 평균 풍속(m/s)                0.6         1.2         1.7         1.9         1.1
# 풍정합(100m)                 509         996        1508        1623         985
# 최다풍향(16방위)                 50          50         290          50          50
#
# ...

# %%
nc_air[(nc_air['최다풍향(16방위)']>=315 )|(nc_air['최다풍향(16방위)']<=45)]
#북풍
nc_air[(nc_air['최다풍향(16방위)']>=45 )&(nc_air['최다풍향(16방위)']<=135)]
#동풍
nc_air[(nc_air['최다풍향(16방위)']>=135 )&(nc_air['최다풍향(16방위)']<=225)]
#남풍
nc_air[(nc_air['최다풍향(16방위)']>=225 )&(nc_air['최다풍향(16방위)']<=315)]
#서풍
# Out:
#              일시  일 미세먼지 농도(㎍/㎥)  평균 풍속(m/s)  최다풍향(16방위)
# 12   2020-01-13              28         2.3         290
# 33   2020-02-03              29         3.1         270
# 47   2020-02-18              29         2.3         290
# 52   2020-02-23              24         2.0         270
# 74   2020-03-16              25         2.8         250
# 109  2020-04-20              19         3.3         250
# 135  2020-05-16              29         1.6         290
# 142  2020-05-24              29         2.9         230
# 147  2020-05-29              30         2.0         290
# 150  2020-06-01              25         3.4         290
# 169  2020-06-26              30         3.2         230
# 170  2020-06-27              29         2.0         250
# 174  2020-07-06              29         2.1         270
# 180  2020-07-16              25         1.8         270
# 185  2020-07-30              18         2.1         230
# 186  2020-07-31              21         2.0         250
# ...

# %%
bad_air[(bad_air['최다풍향(16방위)']>=315 )|(bad_air['최다풍향(16방위)']<=45)]
#북풍
bad_air[(bad_air['최다풍향(16방위)']>=45 )&(bad_air['최다풍향(16방위)']<=135)]
#동풍
bad_air[(bad_air['최다풍향(16방위)']>=135 )&(bad_air['최다풍향(16방위)']<=225)]
#남풍
bad_air[(bad_air['최다풍향(16방위)']>=225 )&(bad_air['최다풍향(16방위)']<=315)]
#서풍
# Out:
#              일시  일 미세먼지 농도(㎍/㎥)  평균 풍속(m/s)  최다풍향(16방위)
# 2    2020-01-03              78         1.7         290
# 9    2020-01-10              73         1.5         290
# 10   2020-01-11              60         1.9         290
# 16   2020-01-17              64         1.5         290
# 17   2020-01-18              68         1.8         270
# 18   2020-01-19              72         2.2         270
# 22   2020-01-23              71         2.0         290
# 23   2020-01-24              82         1.7         290
# 24   2020-01-25              58         1.5         290
# 31   2020-02-01              86         1.7         290
# 32   2020-02-02              90         1.8         290
# 43   2020-02-13              90         1.7         290
# 44   2020-02-14              99         1.2         290
# 46   2020-02-16              58         4.0         270
# 51   2020-02-22              75         4.0         270
# 59   2020-03-01              57         2.0         270
# ...

# %%
wind_where_4=['북풍','동풍','남풍','서풍']

# %%
bad_air_count_4=[len(bad_air[(bad_air['최다풍향(16방위)']>=315 )|(bad_air['최다풍향(16방위)']<=45)]),
              len(bad_air[(bad_air['최다풍향(16방위)']>=45 )&(bad_air['최다풍향(16방위)']<=135)]),
              len(bad_air[(bad_air['최다풍향(16방위)']>=135 )&(bad_air['최다풍향(16방위)']<=225)]),
              len(bad_air[(bad_air['최다풍향(16방위)']>=225 )&(bad_air['최다풍향(16방위)']<=315)])]

# %%
wedgeprops={'width': 0.7, 'edgecolor': 'w', 'linewidth': 5}
plt.figure(figsize=(35, 6))
plt.pie(bad_air_count_4, labels=wind_where_4, autopct='%.1f%%',wedgeprops=wedgeprops)
plt.title('공기질이 안좋을 때 바람이 부는 방향(4방위)')
plt.show()
#공기의 질이 좋지 않은 날은 바림이 어디서 불어 왔는지 보기 위한 그래프

# %%
nc_air_count_4=[len(nc_air[(nc_air['최다풍향(16방위)']>=315 )|(nc_air['최다풍향(16방위)']<=45)]),
              len(nc_air[(nc_air['최다풍향(16방위)']>=45 )&(nc_air['최다풍향(16방위)']<=135)]),
              len(nc_air[(nc_air['최다풍향(16방위)']>=135 )&(nc_air['최다풍향(16방위)']<=225)]),
              len(nc_air[(nc_air['최다풍향(16방위)']>=225 )&(nc_air['최다풍향(16방위)']<=315)])]

# %%
wedgeprops={'width': 0.7, 'edgecolor': 'w', 'linewidth': 5}
plt.figure(figsize=(35, 6))
plt.pie(nc_air_count_4, labels=wind_where_4, autopct='%.1f%%',wedgeprops=wedgeprops)
plt.title('공기질이 좋을 때 바람이 부는 방향(4방위)')
plt.show()
#공기의 질이 좋은날은 바림이 어디서 불어 왔는지 보기 위한 그래프

# %%
wind_where_8=['북풍','북동풍','동풍','남동풍','남풍','남서풍','서풍','북서풍']

# %%
bad_air_count_8=[len(bad_air[(bad_air['최다풍향(16방위)']>=337.5 )|(bad_air['최다풍향(16방위)']<=22.5)]),
              len(bad_air[(bad_air['최다풍향(16방위)']>=22.5 )&(bad_air['최다풍향(16방위)']<=67.5)]),
              len(bad_air[(bad_air['최다풍향(16방위)']>=67.5 )&(bad_air['최다풍향(16방위)']<=112.5)]),
              len(bad_air[(bad_air['최다풍향(16방위)']>=112.5 )&(bad_air['최다풍향(16방위)']<=157.5)]),
              len(bad_air[(bad_air['최다풍향(16방위)']>=157.5 )&(bad_air['최다풍향(16방위)']<=202.5)]),
              len(bad_air[(bad_air['최다풍향(16방위)']>=202.5 )&(bad_air['최다풍향(16방위)']<=247.5)]),
              len(bad_air[(bad_air['최다풍향(16방위)']>=247.5 )&(bad_air['최다풍향(16방위)']<=292.5)]),
              len(bad_air[(bad_air['최다풍향(16방위)']>=292.5 )&(bad_air['최다풍향(16방위)']<=337)])]

# %%
nc_air_count_8=[len(nc_air[(nc_air['최다풍향(16방위)']>=337.5 )|(nc_air['최다풍향(16방위)']<=22.5)]),
              len(nc_air[(nc_air['최다풍향(16방위)']>=22.5 )&(nc_air['최다풍향(16방위)']<=67.5)]),
              len(nc_air[(nc_air['최다풍향(16방위)']>=67.5 )&(nc_air['최다풍향(16방위)']<=112.5)]),
              len(nc_air[(nc_air['최다풍향(16방위)']>=112.5 )&(nc_air['최다풍향(16방위)']<=157.5)]),
              len(nc_air[(nc_air['최다풍향(16방위)']>=157.5 )&(nc_air['최다풍향(16방위)']<=202.5)]),
              len(nc_air[(nc_air['최다풍향(16방위)']>=202.5 )&(nc_air['최다풍향(16방위)']<=247.5)]),
              len(nc_air[(nc_air['최다풍향(16방위)']>=247.5 )&(nc_air['최다풍향(16방위)']<=292.5)]),
              len(nc_air[(nc_air['최다풍향(16방위)']>=292.5 )&(nc_air['최다풍향(16방위)']<=337)])]

# %%
i=22.5
j=45
print(i)
while(i<360):
    print(i+j)
    i=j+i
# Out:
# 22.5
# 67.5
# 112.5
# 157.5
# 202.5
# 247.5
# 292.5
# 337.5
# 382.5

# %%
wedgeprops={'width': 0.7, 'edgecolor': 'w', 'linewidth': 5}
plt.figure(figsize=(35, 6))
plt.pie(bad_air_count_8, labels=wind_where_8, autopct='%.1f%%',wedgeprops=wedgeprops)
plt.title('공기질이 안 좋을 때 바람이 부는 방향(8방위)')
plt.show()

# %%
wedgeprops={'width': 0.7, 'edgecolor': 'w', 'linewidth': 5}
plt.figure(figsize=(35, 6))
plt.pie(nc_air_count_8, labels=wind_where_8, autopct='%.1f%%',wedgeprops=wedgeprops)
plt.title('공기질이 좋을 때 바람이 부는 방향(8방위)')
plt.show()

# %%
i=22.5/2
j=45/2
print(i)
while(i<360):
    print(i+j)
    i=j+i
# Out:
# 11.25
# 33.75
# 56.25
# 78.75
# 101.25
# 123.75
# 146.25
# 168.75
# 191.25
# 213.75
# 236.25
# 258.75
# 281.25
# 303.75
# 326.25
# 348.75
# 371.25

# %%
wind_where_16=['북풍','북북동풍','북동풍','동북동풍',
               '동풍','동남동풍','남동풍','남남동풍',
               '남풍','남남서풍','남서풍','서남서풍',
               '서풍','서북서풍','북서풍','북북서풍',]

# %%
bad_air_count_16=[len(bad_air[(bad_air['최다풍향(16방위)']>=348.75 )|(bad_air['최다풍향(16방위)']<=11.25)]),
                  len(bad_air[(bad_air['최다풍향(16방위)']>=11.25 )&(bad_air['최다풍향(16방위)']<=33.75)]),
                  len(bad_air[(bad_air['최다풍향(16방위)']>=33.75 )&(bad_air['최다풍향(16방위)']<=56.25)]),
                  len(bad_air[(bad_air['최다풍향(16방위)']>=56.25 )&(bad_air['최다풍향(16방위)']<=78.75)]),
                  len(bad_air[(bad_air['최다풍향(16방위)']>=78.75 )&(bad_air['최다풍향(16방위)']<=101.25)]),
                  len(bad_air[(bad_air['최다풍향(16방위)']>=101.25 )&(bad_air['최다풍향(16방위)']<=123.75)]),
                  len(bad_air[(bad_air['최다풍향(16방위)']>=123.75 )&(bad_air['최다풍향(16방위)']<=146.25)]),
                  len(bad_air[(bad_air['최다풍향(16방위)']>=146.25 )&(bad_air['최다풍향(16방위)']<=168.75)]),
                  len(bad_air[(bad_air['최다풍향(16방위)']>=168.75 )&(bad_air['최다풍향(16방위)']<=191.25)]),
                  len(bad_air[(bad_air['최다풍향(16방위)']>=191.25 )&(bad_air['최다풍향(16방위)']<=213.75)]),
                  len(bad_air[(bad_air['최다풍향(16방위)']>=213.75 )&(bad_air['최다풍향(16방위)']<=236.25)]),
                  len(bad_air[(bad_air['최다풍향(16방위)']>=236.25 )&(bad_air['최다풍향(16방위)']<=258.75)]),
                  len(bad_air[(bad_air['최다풍향(16방위)']>=258.75 )&(bad_air['최다풍향(16방위)']<=281.25)]),
                  len(bad_air[(bad_air['최다풍향(16방위)']>=281.25 )&(bad_air['최다풍향(16방위)']<=303.75)]),
                  len(bad_air[(bad_air['최다풍향(16방위)']>=303.75 )&(bad_air['최다풍향(16방위)']<=326.25)]),
                  len(bad_air[(bad_air['최다풍향(16방위)']>=326.25 )&(bad_air['최다풍향(16방위)']<=348.75)])]

# %%
wedgeprops={'width': 0.7, 'edgecolor': 'w', 'linewidth': 5}
plt.figure(figsize=(35, 6))
plt.pie(bad_air_count_16, labels=wind_where_16, autopct='%.1f%%',wedgeprops=wedgeprops)
plt.title('공기질이 안 좋을 때 바람이 부는 방향(16방위)')
plt.show()

# %%
#공기질이 안좋을때는 주로 서풍, 서북서풍,북동풍,북북동풍 주로 이루어져 있습니다.

# %%
nc_air_count_16=[len(nc_air[(nc_air['최다풍향(16방위)']>=348.75 )|(nc_air['최다풍향(16방위)']<=11.25)]),
                  len(nc_air[(nc_air['최다풍향(16방위)']>=11.25 )&(nc_air['최다풍향(16방위)']<=33.75)]),
                  len(nc_air[(nc_air['최다풍향(16방위)']>=33.75 )&(nc_air['최다풍향(16방위)']<=56.25)]),
                  len(nc_air[(nc_air['최다풍향(16방위)']>=56.25 )&(nc_air['최다풍향(16방위)']<=78.75)]),
                  len(nc_air[(nc_air['최다풍향(16방위)']>=78.75 )&(nc_air['최다풍향(16방위)']<=101.25)]),
                  len(nc_air[(nc_air['최다풍향(16방위)']>=101.25 )&(nc_air['최다풍향(16방위)']<=123.75)]),
                  len(nc_air[(nc_air['최다풍향(16방위)']>=123.75 )&(nc_air['최다풍향(16방위)']<=146.25)]),
                  len(nc_air[(nc_air['최다풍향(16방위)']>=146.25 )&(nc_air['최다풍향(16방위)']<=168.75)]),
                  len(nc_air[(nc_air['최다풍향(16방위)']>=168.75 )&(nc_air['최다풍향(16방위)']<=191.25)]),
                  len(nc_air[(nc_air['최다풍향(16방위)']>=191.25 )&(nc_air['최다풍향(16방위)']<=213.75)]),
                  len(nc_air[(nc_air['최다풍향(16방위)']>=213.75 )&(nc_air['최다풍향(16방위)']<=236.25)]),
                  len(nc_air[(nc_air['최다풍향(16방위)']>=236.25 )&(nc_air['최다풍향(16방위)']<=258.75)]),
                  len(nc_air[(nc_air['최다풍향(16방위)']>=258.75 )&(nc_air['최다풍향(16방위)']<=281.25)]),
                  len(nc_air[(nc_air['최다풍향(16방위)']>=281.25 )&(nc_air['최다풍향(16방위)']<=303.75)]),
                  len(nc_air[(nc_air['최다풍향(16방위)']>=303.75 )&(nc_air['최다풍향(16방위)']<=326.25)]),
                  len(nc_air[(nc_air['최다풍향(16방위)']>=326.25 )&(nc_air['최다풍향(16방위)']<=348.75)])]

# %%
wedgeprops={'width': 0.7, 'edgecolor': 'w', 'linewidth': 5}
plt.figure(figsize=(35, 6))
plt.pie(nc_air_count_16, labels=wind_where_16, autopct='%.1f%%',wedgeprops=wedgeprops)
plt.title('공기질이 좋을 때 바람이 부는 방향(8방위)')
plt.show()

# %%
bad_air.T
# Out:
#                        1           2           3           4           9    \
# 일시              2020-01-02  2020-01-03  2020-01-04  2020-01-05  2020-01-10
# 일 미세먼지 농도(㎍/㎥)          69          78          63          62          73
# 평균 풍속(m/s)             1.2         1.7         1.9         1.1         1.5
# 최다풍향(16방위)              50         290          50          50         290
#
#                        10          16          17          18          22   \
# 일시              2020-01-11  2020-01-17  2020-01-18  2020-01-19  2020-01-23
# 일 미세먼지 농도(㎍/㎥)          60          64          68          72          71
# 평균 풍속(m/s)             1.9         1.5         1.8         2.2           2
# 최다풍향(16방위)             290         290         270         270         290
#
#                    ...             278         279         288         289  \
# 일시                 ...      2020-12-10  2020-12-12  2020-12-21  2020-12-22
# ...

# %%
plt.figure(figsize=(20, 5))
plt.bar(bad_air['일 미세먼지 농도(㎍/㎥)'],bad_air['평균 풍속(m/s)'])
plt.title('일 미세먼지 농도가 안 좋은날')
plt.xlabel('일 미세먼지 농도(㎍/㎥)')
plt.ylabel('평균 풍속(m/s)')
plt.show()

# %%
plt.figure(figsize=(20, 5))
plt.bar(nc_air['일 미세먼지 농도(㎍/㎥)'],nc_air['평균 풍속(m/s)'])
plt.title('일 미세먼지 농도가 좋은날')
plt.xlabel('일 미세먼지 농도(㎍/㎥)')
plt.ylabel('평균 풍속(m/s)')
plt.show()

# %%
label=['Nice','Bad']
plt.figure(figsize=(20, 5))
p1=plt.bar(nc_air['일 미세먼지 농도(㎍/㎥)'],nc_air['평균 풍속(m/s)'], label='Bad', color='b', alpha=0.2)
p2=plt.bar(bad_air['일 미세먼지 농도(㎍/㎥)'],bad_air['평균 풍속(m/s)'], label='Nice', color='r', alpha=0.2)
plt.xlabel('일 미세먼지 농도(㎍/㎥)')
plt.ylabel('평균 풍속(m/s)')
plt.title('평균 바람 세기에 따른 미세먼지의 관계(산점도)')
plt.legend((p1,p2),label)
plt.show()
#공기의 질이 좋은날과 안좋은날을 같은 그래프에서 비교하기 위하여 합쳤으며 그래프의 투명도를 낮춰 집중되어있는곳은 진하게 보이게 하였습니다.

# %%
p1=plt.scatter(nc_air['일 미세먼지 농도(㎍/㎥)'],nc_air['평균 풍속(m/s)'], color='b', alpha=0.3,s=100)
p1=plt.scatter(bad_air['일 미세먼지 농도(㎍/㎥)'],bad_air['평균 풍속(m/s)'], color='r', alpha=0.3,s=100)
plt.xlabel('일 미세먼지 농도(㎍/㎥)')
plt.ylabel('평균 풍속(m/s)')
plt.title('평균 바람 세기에 따른 미세먼지의 관계(산점도)')
plt.legend((p1,p2),label)
#평균 바람 세기에 따른 미세먼지의 관계

# %%
plt.scatter(hi_wind['일 미세먼지 농도(㎍/㎥)'],hi_wind['평균 풍속(m/s)'], color='g', alpha=0.5, s=120)
plt.xlabel('일 미세먼지 농도(㎍/㎥)')
plt.ylabel('평균 풍속(m/s)')
plt.title('바람 세기에 따른 미세먼지 농도')
plt.show()
#바람세기에 따른 미세먼지

# %%
nc_air[(nc_air['최다풍향(16방위)']>=33.75 )&(nc_air['최다풍향(16방위)']<=56.25)]['일 미세먼지 농도(㎍/㎥)'].mean()
# Out:
# 16.7

# %%
mean_nc_air_8=[nc_air[(nc_air['최다풍향(16방위)']>=337.5 )|(nc_air['최다풍향(16방위)']<=22.5)]['일 미세먼지 농도(㎍/㎥)'].mean(),
                     nc_air[(nc_air['최다풍향(16방위)']>=22.5 )&(nc_air['최다풍향(16방위)']<=67.5)]['일 미세먼지 농도(㎍/㎥)'].mean(),
                     nc_air[(nc_air['최다풍향(16방위)']>=67.5 )&(nc_air['최다풍향(16방위)']<=112.5)]['일 미세먼지 농도(㎍/㎥)'].mean(),
                     nc_air[(nc_air['최다풍향(16방위)']>=112.5 )&(nc_air['최다풍향(16방위)']<=157.5)]['일 미세먼지 농도(㎍/㎥)'].mean(),
                     nc_air[(nc_air['최다풍향(16방위)']>=157.5 )&(nc_air['최다풍향(16방위)']<=202.5)]['일 미세먼지 농도(㎍/㎥)'].mean(),
                     nc_air[(nc_air['최다풍향(16방위)']>=202.5 )&(nc_air['최다풍향(16방위)']<=247.5)]['일 미세먼지 농도(㎍/㎥)'].mean(),
                     nc_air[(nc_air['최다풍향(16방위)']>=247.5 )&(nc_air['최다풍향(16방위)']<=292.5)]['일 미세먼지 농도(㎍/㎥)'].mean(),
                     nc_air[(nc_air['최다풍향(16방위)']>=292.5 )&(nc_air['최다풍향(16방위)']<=337.5)]['일 미세먼지 농도(㎍/㎥)'].mean()]

# %%
mean_bad_air_16=[
    bad_air[(bad_air['최다풍향(16방위)']>=348.75 )|(bad_air['최다풍향(16방위)']<=11.25)]['일 미세먼지 농도(㎍/㎥)'].mean(),
    bad_air[(bad_air['최다풍향(16방위)']>=11.25 )&(bad_air['최다풍향(16방위)']<=33.75)]['일 미세먼지 농도(㎍/㎥)'].mean(),
    bad_air[(bad_air['최다풍향(16방위)']>=33.75 )&(bad_air['최다풍향(16방위)']<=56.25)]['일 미세먼지 농도(㎍/㎥)'].mean(),
    bad_air[(bad_air['최다풍향(16방위)']>=56.25 )&(bad_air['최다풍향(16방위)']<=78.75)]['일 미세먼지 농도(㎍/㎥)'].mean(),
    bad_air[(bad_air['최다풍향(16방위)']>=78.75 )&(bad_air['최다풍향(16방위)']<=101.25)]['일 미세먼지 농도(㎍/㎥)'].mean(),
    bad_air[(bad_air['최다풍향(16방위)']>=101.25 )&(bad_air['최다풍향(16방위)']<=123.75)]['일 미세먼지 농도(㎍/㎥)'].mean(),
    bad_air[(bad_air['최다풍향(16방위)']>=123.75 )&(bad_air['최다풍향(16방위)']<=146.25)]['일 미세먼지 농도(㎍/㎥)'].mean(),
    bad_air[(bad_air['최다풍향(16방위)']>=146.25 )&(bad_air['최다풍향(16방위)']<=168.75)]['일 미세먼지 농도(㎍/㎥)'].mean(),
    bad_air[(bad_air['최다풍향(16방위)']>=168.75 )&(bad_air['최다풍향(16방위)']<=191.25)]['일 미세먼지 농도(㎍/㎥)'].mean(),
    bad_air[(bad_air['최다풍향(16방위)']>=191.25 )&(bad_air['최다풍향(16방위)']<=213.75)]['일 미세먼지 농도(㎍/㎥)'].mean(),
    bad_air[(bad_air['최다풍향(16방위)']>=213.75 )&(bad_air['최다풍향(16방위)']<=236.25)]['일 미세먼지 농도(㎍/㎥)'].mean(),
    bad_air[(bad_air['최다풍향(16방위)']>=236.25 )&(bad_air['최다풍향(16방위)']<=258.75)]['일 미세먼지 농도(㎍/㎥)'].mean(),
    bad_air[(bad_air['최다풍향(16방위)']>=258.75 )&(bad_air['최다풍향(16방위)']<=281.25)]['일 미세먼지 농도(㎍/㎥)'].mean(),    
    bad_air[(bad_air['최다풍향(16방위)']>=281.25 )&(bad_air['최다풍향(16방위)']<=303.75)]['일 미세먼지 농도(㎍/㎥)'].mean(),
    bad_air[(bad_air['최다풍향(16방위)']>=303.75 )&(bad_air['최다풍향(16방위)']<=326.25)]['일 미세먼지 농도(㎍/㎥)'].mean(),
    bad_air[(bad_air['최다풍향(16방위)']>=326.25 )&(bad_air['최다풍향(16방위)']<=348.75)]['일 미세먼지 농도(㎍/㎥)'].mean()]
mean_bad_air_wind_16=[
    bad_air[(bad_air['최다풍향(16방위)']>=348.75 )|(bad_air['최다풍향(16방위)']<=11.25)]['평균 풍속(m/s)'].mean(),
    bad_air[(bad_air['최다풍향(16방위)']>=11.25 )&(bad_air['최다풍향(16방위)']<=33.75)]['평균 풍속(m/s)'].mean(),
    bad_air[(bad_air['최다풍향(16방위)']>=33.75 )&(bad_air['최다풍향(16방위)']<=56.25)]['평균 풍속(m/s)'].mean(),
    bad_air[(bad_air['최다풍향(16방위)']>=56.25 )&(bad_air['최다풍향(16방위)']<=78.75)]['평균 풍속(m/s)'].mean(),
    bad_air[(bad_air['최다풍향(16방위)']>=78.75 )&(bad_air['최다풍향(16방위)']<=101.25)]['평균 풍속(m/s)'].mean(),
    bad_air[(bad_air['최다풍향(16방위)']>=101.25 )&(bad_air['최다풍향(16방위)']<=123.75)]['평균 풍속(m/s)'].mean(),
    bad_air[(bad_air['최다풍향(16방위)']>=123.75 )&(bad_air['최다풍향(16방위)']<=146.25)]['평균 풍속(m/s)'].mean(),
    bad_air[(bad_air['최다풍향(16방위)']>=146.25 )&(bad_air['최다풍향(16방위)']<=168.75)]['평균 풍속(m/s)'].mean(),
    bad_air[(bad_air['최다풍향(16방위)']>=168.75 )&(bad_air['최다풍향(16방위)']<=191.25)]['평균 풍속(m/s)'].mean(),
    bad_air[(bad_air['최다풍향(16방위)']>=191.25 )&(bad_air['최다풍향(16방위)']<=213.75)]['평균 풍속(m/s)'].mean(),
    bad_air[(bad_air['최다풍향(16방위)']>=213.75 )&(bad_air['최다풍향(16방위)']<=236.25)]['평균 풍속(m/s)'].mean(),
    bad_air[(bad_air['최다풍향(16방위)']>=236.25 )&(bad_air['최다풍향(16방위)']<=258.75)]['평균 풍속(m/s)'].mean(),
    bad_air[(bad_air['최다풍향(16방위)']>=258.75 )&(bad_air['최다풍향(16방위)']<=281.25)]['평균 풍속(m/s)'].mean(),
    bad_air[(bad_air['최다풍향(16방위)']>=281.25 )&(bad_air['최다풍향(16방위)']<=303.75)]['평균 풍속(m/s)'].mean(),
    bad_air[(bad_air['최다풍향(16방위)']>=303.75 )&(bad_air['최다풍향(16방위)']<=326.25)]['평균 풍속(m/s)'].mean(),
    bad_air[(bad_air['최다풍향(16방위)']>=326.25 )&(bad_air['최다풍향(16방위)']<=348.75)]['평균 풍속(m/s)'].mean()]

# %%
plt.rcParams['figure.figsize'] = [15, 5]
fig, ax1 = plt.subplots()
ax1.plot(wind_where_16, mean_bad_air_16,  color='firebrick',alpha=1, label='미세먼지 농도',linewidth = 3,marker="H")
ax1.set_ylim(0, 150)
ax1.set_xlabel('평균 풍향')
ax1.set_ylabel('일 미세먼지 농도(㎍/㎥)')
ax1.tick_params(axis='both', direction='in')

ax2 = ax1.twinx()
ax2.bar(wind_where_16, mean_bad_air_wind_16, color='dodgerblue', label='풍속', alpha=0.8, width=0.7)
ax2.set_ylim(0, 5)
ax2.set_ylabel(r'평균 풍속(m/s)')
ax2.tick_params(axis='y', direction='in')

ax1.set_zorder(ax2.get_zorder() + 10)
ax1.patch.set_visible(False)

ax1.legend(loc='upper left')
ax2.legend(loc='upper right')
plt.title('미세먼지농도가 안좋은날의 풍향별 풍속')
plt.show()

# %%
mean_nc_air_16=[
    nc_air[(nc_air['최다풍향(16방위)']>=348.75 )|(nc_air['최다풍향(16방위)']<=11.25)]['일 미세먼지 농도(㎍/㎥)'].mean(),
    nc_air[(nc_air['최다풍향(16방위)']>=11.25 )&(nc_air['최다풍향(16방위)']<=33.75)]['일 미세먼지 농도(㎍/㎥)'].mean(),
    nc_air[(nc_air['최다풍향(16방위)']>=33.75 )&(nc_air['최다풍향(16방위)']<=56.25)]['일 미세먼지 농도(㎍/㎥)'].mean(),
    nc_air[(nc_air['최다풍향(16방위)']>=56.25 )&(nc_air['최다풍향(16방위)']<=78.75)]['일 미세먼지 농도(㎍/㎥)'].mean(),
    nc_air[(nc_air['최다풍향(16방위)']>=78.75 )&(nc_air['최다풍향(16방위)']<=101.25)]['일 미세먼지 농도(㎍/㎥)'].mean(),
    nc_air[(nc_air['최다풍향(16방위)']>=101.25 )&(nc_air['최다풍향(16방위)']<=123.75)]['일 미세먼지 농도(㎍/㎥)'].mean(),
    nc_air[(nc_air['최다풍향(16방위)']>=123.75 )&(nc_air['최다풍향(16방위)']<=146.25)]['일 미세먼지 농도(㎍/㎥)'].mean(),
    nc_air[(nc_air['최다풍향(16방위)']>=146.25 )&(nc_air['최다풍향(16방위)']<=168.75)]['일 미세먼지 농도(㎍/㎥)'].mean(),
    nc_air[(nc_air['최다풍향(16방위)']>=168.75 )&(nc_air['최다풍향(16방위)']<=191.25)]['일 미세먼지 농도(㎍/㎥)'].mean(),
    nc_air[(nc_air['최다풍향(16방위)']>=191.25 )&(nc_air['최다풍향(16방위)']<=213.75)]['일 미세먼지 농도(㎍/㎥)'].mean(),
    nc_air[(nc_air['최다풍향(16방위)']>=213.75 )&(nc_air['최다풍향(16방위)']<=236.25)]['일 미세먼지 농도(㎍/㎥)'].mean(),
    nc_air[(nc_air['최다풍향(16방위)']>=236.25 )&(nc_air['최다풍향(16방위)']<=258.75)]['일 미세먼지 농도(㎍/㎥)'].mean(),
    nc_air[(nc_air['최다풍향(16방위)']>=258.75 )&(nc_air['최다풍향(16방위)']<=281.25)]['일 미세먼지 농도(㎍/㎥)'].mean(),    
    nc_air[(nc_air['최다풍향(16방위)']>=281.25 )&(nc_air['최다풍향(16방위)']<=303.75)]['일 미세먼지 농도(㎍/㎥)'].mean(),
    nc_air[(nc_air['최다풍향(16방위)']>=303.75 )&(nc_air['최다풍향(16방위)']<=326.25)]['일 미세먼지 농도(㎍/㎥)'].mean(),
    nc_air[(nc_air['최다풍향(16방위)']>=326.25 )&(nc_air['최다풍향(16방위)']<=348.75)]['일 미세먼지 농도(㎍/㎥)'].mean()]
mean_nc_air_wind_16=[
    nc_air[(nc_air['최다풍향(16방위)']>=348.75 )|(nc_air['최다풍향(16방위)']<=11.25)]['평균 풍속(m/s)'].mean(),
    nc_air[(nc_air['최다풍향(16방위)']>=11.25 )&(nc_air['최다풍향(16방위)']<=33.75)]['평균 풍속(m/s)'].mean(),
    nc_air[(nc_air['최다풍향(16방위)']>=33.75 )&(nc_air['최다풍향(16방위)']<=56.25)]['평균 풍속(m/s)'].mean(),
    nc_air[(nc_air['최다풍향(16방위)']>=56.25 )&(nc_air['최다풍향(16방위)']<=78.75)]['평균 풍속(m/s)'].mean(),
    nc_air[(nc_air['최다풍향(16방위)']>=78.75 )&(nc_air['최다풍향(16방위)']<=101.25)]['평균 풍속(m/s)'].mean(),
    nc_air[(nc_air['최다풍향(16방위)']>=101.25 )&(nc_air['최다풍향(16방위)']<=123.75)]['평균 풍속(m/s)'].mean(),
    nc_air[(nc_air['최다풍향(16방위)']>=123.75 )&(nc_air['최다풍향(16방위)']<=146.25)]['평균 풍속(m/s)'].mean(),
    nc_air[(nc_air['최다풍향(16방위)']>=146.25 )&(nc_air['최다풍향(16방위)']<=168.75)]['평균 풍속(m/s)'].mean(),
    nc_air[(nc_air['최다풍향(16방위)']>=168.75 )&(nc_air['최다풍향(16방위)']<=191.25)]['평균 풍속(m/s)'].mean(),
    nc_air[(nc_air['최다풍향(16방위)']>=191.25 )&(nc_air['최다풍향(16방위)']<=213.75)]['평균 풍속(m/s)'].mean(),
    nc_air[(nc_air['최다풍향(16방위)']>=213.75 )&(nc_air['최다풍향(16방위)']<=236.25)]['평균 풍속(m/s)'].mean(),
    nc_air[(nc_air['최다풍향(16방위)']>=236.25 )&(nc_air['최다풍향(16방위)']<=258.75)]['평균 풍속(m/s)'].mean(),
    nc_air[(nc_air['최다풍향(16방위)']>=258.75 )&(nc_air['최다풍향(16방위)']<=281.25)]['평균 풍속(m/s)'].mean(),
    nc_air[(nc_air['최다풍향(16방위)']>=281.25 )&(nc_air['최다풍향(16방위)']<=303.75)]['평균 풍속(m/s)'].mean(),
    nc_air[(nc_air['최다풍향(16방위)']>=303.75 )&(nc_air['최다풍향(16방위)']<=326.25)]['평균 풍속(m/s)'].mean(),
    nc_air[(nc_air['최다풍향(16방위)']>=326.25 )&(nc_air['최다풍향(16방위)']<=348.75)]['평균 풍속(m/s)'].mean()]

# %%
plt.rcParams['figure.figsize'] = [15, 5]
fig, ax1 = plt.subplots()
ax1.plot(wind_where_16, mean_nc_air_16,  color='forestgreen',alpha=1, label='미세먼지 농도',linewidth = 3,marker="H")
ax1.set_ylim(0, 150)
ax1.set_xlabel('평균 풍향')
ax1.set_ylabel('일 미세먼지 농도(㎍/㎥)')
ax1.tick_params(axis='both', direction='in')

ax2 = ax1.twinx()
ax2.bar(wind_where_16, mean_nc_air_wind_16, color='dodgerblue', label='풍속', alpha=0.8, width=0.7)
ax2.set_ylim(0, 5)
ax2.set_ylabel(r'평균 풍속(m/s)')
ax2.tick_params(axis='y', direction='in')

ax1.set_zorder(ax2.get_zorder() + 10)
ax1.patch.set_visible(False)

ax1.legend(loc='upper left')
ax2.legend(loc='upper right')
plt.title('미세먼지농도가 좋은날의 풍향별 풍속')
plt.show()
